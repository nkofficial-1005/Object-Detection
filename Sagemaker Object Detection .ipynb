# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already up-to-date: pillow in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (7.2.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/english_setter_165.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):#bounding box
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'english_setter_165.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 500, 'height': 375, 'depth': 3}],
#  'annotations': [{'class_id': 1,
#    'left': 114,
#    'top': 93,
#    'width': 91,
#    'height': 102}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img) #using pillow
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role= sagemaker.get_execution_role()
bucket_name = 'petdataset'

training_image = get_image_uri(boto3.Session().region_name,'object-detection',repo_version='latest')

print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')#target set can be train or validation
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 2277.40it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2755 2755

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess = sagemaker.Session()

print('Uploading data')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')
s3_validation_path = sess.upload_data(path='validation',bucket=bucket_name,key_prefix='validation')
print('Validation images uploaded')

s3_train_annotation = sess.upload_data(path='train_annotation', bucket=bucket_name, key_prefix='train_annotation')
print('Training annotations uploaded')
s3_validation_annotation = sess.upload_data(path='validation_annotation',bucket=bucket_name,key_prefix='validation_annotation')
print('Validation annotations uploaded')
# Out:
# Uploading data
# Training images uploaded
# Validation images uploaded
# Training annotations uploaded
# Validation annotations uploaded

# %%
s3_validation_annotation
# Out:
# 's3://petdataset/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    train_instance_type='ml.p3.2xlarge',
    train_instance_count=1,
    train_volume_size=100,
    train_max_run=36000,
    input_mode='File',
    output_path='s3://petdataset/output',
    sagemaker_session=sess
)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    optimizer='sgd',
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input

train_data=sagemaker.session.s3_input(s3_train_path, distribution='FullyReplicated',
                                     content_type='application/x-image',s3_data_type='S3Prefix')

validation_data=sagemaker.session.s3_input(s3_validation_path, distribution='FullyReplicated',
                                     content_type='application/x-image',s3_data_type='S3Prefix')

train_annotation_data=sagemaker.session.s3_input(s3_train_annotation, distribution='FullyReplicated',
                                     content_type='application/x-image',s3_data_type='S3Prefix')

validation_annotation_data=sagemaker.session.s3_input(s3_validation_annotation, distribution='FullyReplicated',
                                     content_type='application/x-image',s3_data_type='S3Prefix')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels={
    'train':train_data,
    'validation':validation_data,
    'train_annotation':train_annotation_data,
    'validation_annotation':validation_annotation_data    
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7fd49b50c7b8>,
#  'validation': <sagemaker.inputs.s3_input at 0x7fd49b50ca58>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7fd49b50c748>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7fd49b50c668>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# 2020-10-05 05:44:26 Starting - Starting the training job...
# 2020-10-05 05:44:28 Starting - Launching requested ML instances......
# 2020-10-05 05:45:28 Starting - Preparing the instances for training......
# 2020-10-05 05:46:38 Downloading - Downloading input data.........
# 2020-10-05 05:48:20 Training - Downloading the training image...
# 2020-10-05 05:48:41 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [10/05/2020 05:48:45 INFO 140682124392256] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [10/05/2020 05:48:45 INFO 140682124392256] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2755', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [10/05/2020 05:48:45 INFO 140682124392256] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2755', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [10/05/2020 05:48:45 INFO 140682124392256] Using default worker.
# [10/05/2020 05:48:45 INFO 140682124392256] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/05/2020 05:48:45 INFO 140682124392256] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/05/2020 05:48:45 INFO 140682124392256] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/05/2020 05:48:45 INFO 140682124392256] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/05/2020 05:48:45 INFO 140682124392256] Checkpoint loading and saving are disabled.
# [10/05/2020 05:48:47 INFO 140682124392256] nvidia-smi took: 0.0252430438995 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0307438373566  count: 0
# time: 1.35086917877  count: 1000
# Corrupt JPEG data: premature end of data segment
# time: 1.24470996857  count: 2000
# time: 1.32523584366  count: 3000
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.00938606262207  count: 0
# time: 2.10729312897  count: 1000
# Corrupt JPEG data: premature end of data segment
# time: 1.19618082047  count: 2000
# [10/05/2020 05:48:59 INFO 140682124392256] Number of GPUs being used: 1
# [10/05/2020 05:48:59 WARNING 140682124392256] Training images are resized to image shape (3, 512, 512)
# [05:48:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [05:48:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [10/05/2020 05:49:01 WARNING 140682124392256] Validation images are resized to image shape (3, 512, 512)
# [05:49:01] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [05:49:01] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [10/05/2020 05:49:03 INFO 140682124392256] Number of GPUs being used: 1
# [10/05/2020 05:49:03 INFO 140682124392256] Using [gpu(0)] as training context.
# [10/05/2020 05:49:03 INFO 140682124392256] Number of GPUs being used: 1
# [10/05/2020 05:49:03 INFO 140682124392256] Create Store: device
# [10/05/2020 05:49:03 INFO 140682124392256] Using (gpu(0)) as training context.
# [10/05/2020 05:49:03 INFO 140682124392256] Start training from pretrained model 1.
# [05:49:03] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [05:49:03] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [10/05/2020 05:49:04 INFO 140682124392256] Loaded pretrained model parameters.
# [10/05/2020 05:49:18 INFO 140682124392256] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1601876958.884869, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1601876958.884786}
#
# [05:49:19] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/05/2020 05:49:56 INFO 140682124392256] Epoch:    0, batches:    100, num_examples:   1600, 42.7 samples/sec, epoch time so far:  0:00:37.450486
# [10/05/2020 05:50:27 INFO 140682124392256] Epoch:    0, batches:    200, num_examples:   3200, 46.5 samples/sec, epoch time so far:  0:01:08.805974
# [10/05/2020 05:50:36 INFO 140682124392256] #quality_metric: host=algo-1, epoch=0, batch=231 train cross_entropy <loss>=(1.0627325790688809)
# [10/05/2020 05:50:36 INFO 140682124392256] #quality_metric: host=algo-1, epoch=0, batch=231 train smooth_l1 <loss>=(0.630189379770556)
# [10/05/2020 05:50:36 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:50:37 INFO 140682124392256] Updated the metrics
# [10/05/2020 05:51:12 INFO 140682124392256] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.19299522978335648)
# [10/05/2020 05:51:12 INFO 140682124392256] Updating the best model with validation-mAP=0.19299522978335648
# [10/05/2020 05:51:12 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 05:51:12 INFO 140682124392256] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1601877072.508171, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1601876958.885398}
#
# [10/05/2020 05:51:45 INFO 140682124392256] Epoch:    1, batches:    100, num_examples:   1600, 48.5 samples/sec, epoch time so far:  0:00:33.002794
# [10/05/2020 05:52:17 INFO 140682124392256] Epoch:    1, batches:    200, num_examples:   3200, 49.2 samples/sec, epoch time so far:  0:01:04.988444
# [10/05/2020 05:52:26 INFO 140682124392256] #quality_metric: host=algo-1, epoch=1, batch=230 train cross_entropy <loss>=(0.7841748763276342)
# [10/05/2020 05:52:26 INFO 140682124392256] #quality_metric: host=algo-1, epoch=1, batch=230 train smooth_l1 <loss>=(0.5590652721386524)
# [10/05/2020 05:52:26 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:52:26 INFO 140682124392256] Updated the metrics
# [10/05/2020 05:53:00 INFO 140682124392256] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.4779838510975929)
# [10/05/2020 05:53:00 INFO 140682124392256] Updating the best model with validation-mAP=0.4779838510975929
# [10/05/2020 05:53:00 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 05:53:00 INFO 140682124392256] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1601877180.56854, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1601877072.508414}
#
# [10/05/2020 05:53:32 INFO 140682124392256] Epoch:    2, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.399751
# [10/05/2020 05:54:04 INFO 140682124392256] Epoch:    2, batches:    200, num_examples:   3200, 50.3 samples/sec, epoch time so far:  0:01:03.580430
# [10/05/2020 05:54:13 INFO 140682124392256] #quality_metric: host=algo-1, epoch=2, batch=230 train cross_entropy <loss>=(0.6619027845583021)
# [10/05/2020 05:54:13 INFO 140682124392256] #quality_metric: host=algo-1, epoch=2, batch=230 train smooth_l1 <loss>=(0.4677088917669762)
# [10/05/2020 05:54:13 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:54:13 INFO 140682124392256] Updated the metrics
# [10/05/2020 05:54:48 INFO 140682124392256] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.8133184857290192)
# [10/05/2020 05:54:48 INFO 140682124392256] Updating the best model with validation-mAP=0.8133184857290192
# [10/05/2020 05:54:48 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 05:54:48 INFO 140682124392256] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1601877288.512414, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1601877180.568782}
#
# [10/05/2020 05:55:21 INFO 140682124392256] Epoch:    3, batches:    100, num_examples:   1600, 48.8 samples/sec, epoch time so far:  0:00:32.768541
# [10/05/2020 05:55:52 INFO 140682124392256] Epoch:    3, batches:    200, num_examples:   3200, 49.8 samples/sec, epoch time so far:  0:01:04.228254
# [10/05/2020 05:56:01 INFO 140682124392256] #quality_metric: host=algo-1, epoch=3, batch=230 train cross_entropy <loss>=(0.5926012938050018)
# [10/05/2020 05:56:01 INFO 140682124392256] #quality_metric: host=algo-1, epoch=3, batch=230 train smooth_l1 <loss>=(0.367998342767393)
# [10/05/2020 05:56:01 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:56:01 INFO 140682124392256] Updated the metrics
# [10/05/2020 05:56:39 INFO 140682124392256] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.9058935350736355)
# [10/05/2020 05:56:39 INFO 140682124392256] Updating the best model with validation-mAP=0.9058935350736355
# [10/05/2020 05:56:39 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 05:56:39 INFO 140682124392256] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1601877399.653478, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1601877288.51263}
#
# [10/05/2020 05:57:12 INFO 140682124392256] Epoch:    4, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.611480
# [10/05/2020 05:57:43 INFO 140682124392256] Epoch:    4, batches:    200, num_examples:   3200, 50.0 samples/sec, epoch time so far:  0:01:03.989259
# [10/05/2020 05:57:52 INFO 140682124392256] #quality_metric: host=algo-1, epoch=4, batch=230 train cross_entropy <loss>=(0.5500392128826793)
# [10/05/2020 05:57:52 INFO 140682124392256] #quality_metric: host=algo-1, epoch=4, batch=230 train smooth_l1 <loss>=(0.31158202746178265)
# [10/05/2020 05:57:52 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:57:52 INFO 140682124392256] Updated the metrics
# [10/05/2020 05:58:30 INFO 140682124392256] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.9644070196760532)
# [10/05/2020 05:58:30 INFO 140682124392256] Updating the best model with validation-mAP=0.9644070196760532
# [10/05/2020 05:58:30 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 05:58:30 INFO 140682124392256] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1601877510.665998, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1601877399.653678}
#
# [10/05/2020 05:59:03 INFO 140682124392256] Epoch:    5, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.349745
# [10/05/2020 05:59:34 INFO 140682124392256] Epoch:    5, batches:    200, num_examples:   3200, 50.2 samples/sec, epoch time so far:  0:01:03.736468
# [10/05/2020 05:59:43 INFO 140682124392256] #quality_metric: host=algo-1, epoch=5, batch=231 train cross_entropy <loss>=(0.5236523190942788)
# [10/05/2020 05:59:43 INFO 140682124392256] #quality_metric: host=algo-1, epoch=5, batch=231 train smooth_l1 <loss>=(0.2723345805734321)
# [10/05/2020 05:59:43 INFO 140682124392256] Round of batches complete
# [10/05/2020 05:59:43 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:00:22 INFO 140682124392256] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.9816092338351825)
# [10/05/2020 06:00:22 INFO 140682124392256] Updating the best model with validation-mAP=0.9816092338351825
# [10/05/2020 06:00:22 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:00:22 INFO 140682124392256] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1601877622.507974, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1601877510.66625}
#
# [10/05/2020 06:00:54 INFO 140682124392256] Epoch:    6, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.423913
# [10/05/2020 06:01:25 INFO 140682124392256] Epoch:    6, batches:    200, num_examples:   3200, 50.5 samples/sec, epoch time so far:  0:01:03.410311
# [10/05/2020 06:01:34 INFO 140682124392256] #quality_metric: host=algo-1, epoch=6, batch=230 train cross_entropy <loss>=(0.49679025672872934)
# [10/05/2020 06:01:34 INFO 140682124392256] #quality_metric: host=algo-1, epoch=6, batch=230 train smooth_l1 <loss>=(0.24258695104635355)
# [10/05/2020 06:01:34 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:01:35 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:02:13 INFO 140682124392256] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9866297191550549)
# [10/05/2020 06:02:13 INFO 140682124392256] Updating the best model with validation-mAP=0.9866297191550549
# [10/05/2020 06:02:13 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:02:13 INFO 140682124392256] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1601877733.850072, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1601877622.508204}
#
# [10/05/2020 06:02:46 INFO 140682124392256] Epoch:    7, batches:    100, num_examples:   1600, 49.7 samples/sec, epoch time so far:  0:00:32.188936
# [10/05/2020 06:03:17 INFO 140682124392256] Epoch:    7, batches:    200, num_examples:   3200, 50.4 samples/sec, epoch time so far:  0:01:03.476130
# [10/05/2020 06:03:26 INFO 140682124392256] #quality_metric: host=algo-1, epoch=7, batch=230 train cross_entropy <loss>=(0.4660525679108954)
# [10/05/2020 06:03:26 INFO 140682124392256] #quality_metric: host=algo-1, epoch=7, batch=230 train smooth_l1 <loss>=(0.22038942482045953)
# [10/05/2020 06:03:26 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:03:26 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:04:05 INFO 140682124392256] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9936376457554357)
# [10/05/2020 06:04:05 INFO 140682124392256] Updating the best model with validation-mAP=0.9936376457554357
# [10/05/2020 06:04:05 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:04:05 INFO 140682124392256] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1601877845.388302, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1601877733.850314}
#
# [10/05/2020 06:04:37 INFO 140682124392256] Epoch:    8, batches:    100, num_examples:   1600, 49.8 samples/sec, epoch time so far:  0:00:32.100683
# [10/05/2020 06:05:08 INFO 140682124392256] Epoch:    8, batches:    200, num_examples:   3200, 50.8 samples/sec, epoch time so far:  0:01:02.951092
# [10/05/2020 06:05:17 INFO 140682124392256] #quality_metric: host=algo-1, epoch=8, batch=230 train cross_entropy <loss>=(0.4505373821508732)
# [10/05/2020 06:05:17 INFO 140682124392256] #quality_metric: host=algo-1, epoch=8, batch=230 train smooth_l1 <loss>=(0.2018160967516279)
# [10/05/2020 06:05:17 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:05:17 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:05:55 INFO 140682124392256] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9944027585087026)
# [10/05/2020 06:05:55 INFO 140682124392256] Updating the best model with validation-mAP=0.9944027585087026
# [10/05/2020 06:05:55 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:05:56 INFO 140682124392256] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1601877956.012699, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1601877845.388474}
#
# [10/05/2020 06:06:28 INFO 140682124392256] Epoch:    9, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.368111
# [10/05/2020 06:06:59 INFO 140682124392256] Epoch:    9, batches:    200, num_examples:   3200, 50.4 samples/sec, epoch time so far:  0:01:03.535976
# [10/05/2020 06:07:08 INFO 140682124392256] #quality_metric: host=algo-1, epoch=9, batch=230 train cross_entropy <loss>=(0.43722723386596163)
# [10/05/2020 06:07:08 INFO 140682124392256] #quality_metric: host=algo-1, epoch=9, batch=230 train smooth_l1 <loss>=(0.19189103050416442)
# [10/05/2020 06:07:08 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:07:08 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:07:46 INFO 140682124392256] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.993085696017504)
# [10/05/2020 06:07:46 INFO 140682124392256] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1601878066.700352, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1601877956.012954}
#
# [10/05/2020 06:08:18 INFO 140682124392256] Epoch:    10, batches:    100, num_examples:   1600, 49.9 samples/sec, epoch time so far:  0:00:32.038577
# [10/05/2020 06:08:49 INFO 140682124392256] Epoch:    10, batches:    200, num_examples:   3200, 50.7 samples/sec, epoch time so far:  0:01:03.123535
# [10/05/2020 06:08:59 INFO 140682124392256] #quality_metric: host=algo-1, epoch=10, batch=231 train cross_entropy <loss>=(0.4199992013976701)
# [10/05/2020 06:08:59 INFO 140682124392256] #quality_metric: host=algo-1, epoch=10, batch=231 train smooth_l1 <loss>=(0.17889978992029743)
# [10/05/2020 06:08:59 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:08:59 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:09:36 INFO 140682124392256] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9954615803652829)
# [10/05/2020 06:09:36 INFO 140682124392256] Updating the best model with validation-mAP=0.9954615803652829
# [10/05/2020 06:09:36 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:09:36 INFO 140682124392256] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1601878176.611916, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1601878066.700606}
#
# [10/05/2020 06:10:08 INFO 140682124392256] Epoch:    11, batches:    100, num_examples:   1600, 49.7 samples/sec, epoch time so far:  0:00:32.187076
# [10/05/2020 06:10:39 INFO 140682124392256] Epoch:    11, batches:    200, num_examples:   3200, 50.6 samples/sec, epoch time so far:  0:01:03.223643
# [10/05/2020 06:10:48 INFO 140682124392256] #quality_metric: host=algo-1, epoch=11, batch=230 train cross_entropy <loss>=(0.4056227605233916)
# [10/05/2020 06:10:48 INFO 140682124392256] #quality_metric: host=algo-1, epoch=11, batch=230 train smooth_l1 <loss>=(0.16943920666756254)
# [10/05/2020 06:10:48 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:10:48 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:11:22 INFO 140682124392256] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9953246561893191)
# [10/05/2020 06:11:22 INFO 140682124392256] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1601878282.264886, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1601878176.612202}
#
# [10/05/2020 06:11:53 INFO 140682124392256] Epoch:    12, batches:    100, num_examples:   1600, 50.8 samples/sec, epoch time so far:  0:00:31.491368
# [10/05/2020 06:12:24 INFO 140682124392256] Epoch:    12, batches:    200, num_examples:   3200, 51.3 samples/sec, epoch time so far:  0:01:02.401149
# [10/05/2020 06:12:33 INFO 140682124392256] #quality_metric: host=algo-1, epoch=12, batch=230 train cross_entropy <loss>=(0.39960468320465176)
# [10/05/2020 06:12:33 INFO 140682124392256] #quality_metric: host=algo-1, epoch=12, batch=230 train smooth_l1 <loss>=(0.16451891592723505)
# [10/05/2020 06:12:33 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:12:33 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:13:05 INFO 140682124392256] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9961765719509782)
# [10/05/2020 06:13:05 INFO 140682124392256] Updating the best model with validation-mAP=0.9961765719509782
# [10/05/2020 06:13:05 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:13:05 INFO 140682124392256] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1601878385.586506, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1601878282.265128}
#
# [10/05/2020 06:13:37 INFO 140682124392256] Epoch:    13, batches:    100, num_examples:   1600, 50.5 samples/sec, epoch time so far:  0:00:31.705724
# [10/05/2020 06:14:08 INFO 140682124392256] Epoch:    13, batches:    200, num_examples:   3200, 51.1 samples/sec, epoch time so far:  0:01:02.572491
# [10/05/2020 06:14:16 INFO 140682124392256] #quality_metric: host=algo-1, epoch=13, batch=230 train cross_entropy <loss>=(0.3802663439880953)
# [10/05/2020 06:14:16 INFO 140682124392256] #quality_metric: host=algo-1, epoch=13, batch=230 train smooth_l1 <loss>=(0.15351566870041905)
# [10/05/2020 06:14:16 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:14:17 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:14:45 INFO 140682124392256] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9971314896853662)
# [10/05/2020 06:14:45 INFO 140682124392256] Updating the best model with validation-mAP=0.9971314896853662
# [10/05/2020 06:14:46 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:14:46 INFO 140682124392256] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1601878486.088397, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1601878385.586676}
#
# [10/05/2020 06:15:17 INFO 140682124392256] Epoch:    14, batches:    100, num_examples:   1600, 50.5 samples/sec, epoch time so far:  0:00:31.700632
# [10/05/2020 06:15:48 INFO 140682124392256] Epoch:    14, batches:    200, num_examples:   3200, 51.5 samples/sec, epoch time so far:  0:01:02.145657
# [10/05/2020 06:15:57 INFO 140682124392256] #quality_metric: host=algo-1, epoch=14, batch=230 train cross_entropy <loss>=(0.3748160378788908)
# [10/05/2020 06:15:57 INFO 140682124392256] #quality_metric: host=algo-1, epoch=14, batch=230 train smooth_l1 <loss>=(0.14894381405428797)
# [10/05/2020 06:15:57 INFO 140682124392256] Round of batches complete
# [10/05/2020 06:15:57 INFO 140682124392256] Updated the metrics
# [10/05/2020 06:16:24 INFO 140682124392256] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9964191213187492)
# [10/05/2020 06:16:24 INFO 140682124392256] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1601878584.266245, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1601878486.08864}
#
# [10/05/2020 06:16:24 WARNING 140682124392256] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/05/2020 06:16:24 INFO 140682124392256] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/05/2020 06:16:24 INFO 140682124392256] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1659169.6360111237, "sum": 1659169.6360111237, "min": 1659169.6360111237}, "setuptime": {"count": 1, "max": 10.727882385253906, "sum": 10.727882385253906, "min": 10.727882385253906}}, "EndTime": 1601878584.735914, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1601876925.691516}
#
#
# 2020-10-05 06:16:43 Uploading - Uploading generated training model
# 2020-10-05 06:16:43 Completed - Training job completed
# Training seconds: 1805
# Billable seconds: 1805

# %% [markdown]
# # Deploy Model

# %%
deployed_model =  model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!
# Model deployed

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 931

# %%
deployed_model.content_type='image/jpeg'

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction'] #we have list of bounging boxes that are preicted
#print(results) #we get the dictionary from this

# %%
preds
#preds[0]
# Out:
# [[0.0,
#   0.9804649353027344,
#   0.03779497742652893,
#   0.16114601492881775,
#   0.287087082862854,
#   0.6687644720077515],
#  [1.0,
#   0.05595053359866142,
#   0.15114647150039673,
#   0.042715370655059814,
#   0.8378537893295288,
#   0.8462200164794922],
#  [0.0,
#   0.019531557336449623,
#   0.039604656398296356,
#   0.3193545937538147,
#   0.210365891456604,
#   0.525093674659729],
#  [0.0,
#   0.01747245341539383,
#   0.0077058374881744385,
#   0.08723825216293335,
#   0.6318635940551758,
#   0.6854601502418518],
#  [1.0,
#   0.017426928505301476,
#   0.16800804436206818,
#   0.23518888652324677,
#   0.2396450787782669,
#   0.36844485998153687],
#  [1.0,
#   0.014921079389750957,
#   0.19618743658065796,
#   0.2339397668838501,
#   0.2654770016670227,
#   0.36969441175460815],
#  [1.0, 0.014366167597472668, 0.9107286334037781, 0.8334172368049622, 1.0, 1.0],
#  [1.0, 0.014162278734147549, 0.81760573387146, 0.9044414162635803, 1.0, 1.0],
#  [1.0, 0.01351434551179409, 0.0, 0.8982111215591431, 0.16100363433361053, 1.0],
#  [1.0, 0.01323631964623928, 0.0, 0.8330905437469482, 0.09080144762992859, 1.0],
#  [1.0,
#   0.013176796957850456,
#   0.6374527215957642,
#   0.7034076452255249,
#   0.7062536478042603,
#   0.833910346031189],
#  [1.0,
#   0.012626529671251774,
#   0.47996407747268677,
#   0.15811043977737427,
#   0.9799947142601013,
#   0.936971127986908],
#  [1.0,
#   0.01230722013860941,
#   0.5401731133460999,
#   0.9503501057624817,
#   0.6714354157447815,
#   1.0],
#  [0.0, 0.0120442109182477, 0.0, 0.8393098711967468, 0.1008177101612091, 1.0],
#  [0.0, 0.012006337754428387, 0.916998028755188, 0.9480167031288147, 1.0, 1.0],
#  [1.0,
#   0.011962994933128357,
#   0.5989231467247009,
#   0.9505984783172607,
#   0.7320651412010193,
#   1.0],
#  [1.0,
#   0.011768443509936333,
#   0.3483084440231323,
#   0.9508501887321472,
#   0.48388779163360596,
#   1.0],
#  [1.0,
#   0.011159325949847698,
#   0.6663698554039001,
#   0.08325882256031036,
#   0.7406001687049866,
#   0.20694322884082794],
#  [1.0,
#   0.01111399382352829,
#   0.6362162232398987,
#   0.08353614062070847,
#   0.7094190716743469,
#   0.20896810293197632],
#  [1.0,
#   0.011108126491308212,
#   0.7591705322265625,
#   0.950523853302002,
#   0.8907885551452637,
#   1.0],
#  [1.0,
#   0.010750912129878998,
#   0.12756389379501343,
#   0.7075271606445312,
#   0.23012229800224304,
#   0.8208951950073242],
#  [1.0,
#   0.010734746232628822,
#   0.0,
#   0.38126853108406067,
#   0.2495502233505249,
#   1.0],
#  [0.0,
#   0.010714863426983356,
#   0.16888916492462158,
#   0.17591625452041626,
#   0.24040904641151428,
#   0.3067367672920227],
#  [1.0,
#   0.01051363069564104,
#   0.0,
#   0.8288156986236572,
#   0.05036456882953644,
#   0.9586933851242065],
#  [1.0,
#   0.010487549938261509,
#   0.6624655723571777,
#   0.951873779296875,
#   0.7980250120162964,
#   1.0],
#  [1.0,
#   0.010410869494080544,
#   0.19795751571655273,
#   0.949901282787323,
#   0.3301955461502075,
#   1.0],
#  [1.0, 0.01039283536374569, 0.907329261302948, 0.0, 1.0, 0.1600916087627411],
#  [0.0,
#   0.010199490934610367,
#   0.11899100989103317,
#   0.6679818034172058,
#   0.2938544452190399,
#   0.8328922390937805],
#  [1.0,
#   0.01010975707322359,
#   0.2570139765739441,
#   0.9499167799949646,
#   0.3917393684387207,
#   1.0],
#  [1.0,
#   0.010078945197165012,
#   0.7296717762947083,
#   0.17834797501564026,
#   0.8021768927574158,
#   0.2993433177471161]]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred #extracting the information out of each prediction
        
    if score > 0.7: #threshold
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %% [markdown]
# Don't forget!! You need to delete endpoint or else you will continue to accrue cost!

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
